# %%
# !git clone https://github.com/joonkeekim/hare-hate-speech.git
# Out:
# Cloning into 'hare-hate-speech'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 43 (delta 16), reused 36 (delta 12), pack-reused 0 (from 0)
# Receiving objects: 100% (43/43), 358.17 KiB | 11.94 MiB/s, done.
# Resolving deltas: 100% (16/16), done.

# %%
# %cd hare-hate-speech
# Out:
# /content/hare-hate-speech

# %%
# !pip uninstall -y transformers peft accelerate
# !pip install transformers==4.31.0
# !pip install peft==0.4.0
# !pip install accelerate==0.21.0
# !pip install datasets openai backoff evaluate rouge_score scikit-learn deepspeed
# Out:
# Found existing installation: transformers 4.41.2
# Uninstalling transformers-4.41.2:
#   Successfully uninstalled transformers-4.41.2
# Found existing installation: peft 0.7.1
# Uninstalling peft-0.7.1:
#   Successfully uninstalled peft-0.7.1
# Found existing installation: accelerate 1.9.0
# Uninstalling accelerate-1.9.0:
#   Successfully uninstalled accelerate-1.9.0
# ...
#   Using cached transformers-4.31.0-py3-none-any.whl.metadata (116 kB)
# ...
#   Using cached tokenizers-0.13.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# ...
# Using cached transformers-4.31.0-py3-none-any.whl (7.4 MB)
# Using cached tokenizers-0.13.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
# ...

# %%
# %cd /content/hare-hate-speech

# 设置路径变量（注意引号是标准英文引号 " "）
drive_path="/content/drive/MyDrive/upload/[EMNLP 2023] HARE_ Explainable Hate Speech Detection with Step-by-Step Reasoning"
# Out:
# /content/hare-hate-speech

# %%
# 复制 tar.gz 文件
# !cp "$drive_path/implicit-hate.tar.gz" .
# !cp "$drive_path/sbic.tar.gz" .
# !cp "$drive_path/cross_eval.tar.gz" .

# 解压到指定目录
# !mkdir -p data/implicit-hate
# !tar -xzvf implicit-hate.tar.gz -C data/implicit-hate --strip-components=1

# !mkdir -p data/sbic
# !tar -xzvf sbic.tar.gz -C data/sbic --strip-components=1

# !mkdir -p data/cross_eval
# !tar -xzvf cross_eval.tar.gz -C data/cross_eval --strip-components=1
# Out:
# implicit-hate/IH_test.csv
# implicit-hate/IH_exp_co_hare.json
# implicit-hate/IH_exp_fr_hare.json
# implicit-hate/IH_exp_val.json
# implicit-hate/IH_val.csv
# implicit-hate/IH_exp_test.json
# implicit-hate/IH_train.csv
# implicit-hate/IH_exp_cti.json
# sbic/sbic_train_co_hare.json
# sbic/sbic_valid.json
# sbic/sbic_train.json
# sbic/sbic_train_fr_hare.json
# sbic/sbic_test.json
# cross_eval/hateX_test.json
# cross_eval/dynahate_test.json

# %%
# !wandb login --relogin
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin

# %%
# !wandb login
# Out:
# wandb: Currently logged in as: 2045982351 (2045982351-central-china-normal-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
# !bash scripts/ih_baseline_c.sh
# Out:
# 2025-07-28 02:45:03.749218: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753670703.769641   28980 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753670703.775894   28980 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [2025-07-28 02:45:08,584] [INFO] [real_accelerator.py:254:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-07-28 02:45:10,816] [INFO] [logging.py:107:log_dist] [Rank -1] [TorchCheckpointEngine] Initialized with serialization = False
# ...

# %%
# !bash scripts/ih_co_hare.sh
# Out:
# 2025-07-28 03:45:15.104555: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753674315.125340   44086 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753674315.131468   44086 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [2025-07-28 03:45:19,963] [INFO] [real_accelerator.py:254:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-07-28 03:45:21,595] [INFO] [logging.py:107:log_dist] [Rank -1] [TorchCheckpointEngine] Initialized with serialization = False
# ...

# %%
# !bash scripts/sbic_baseline_c.sh
# Out:
# 2025-07-28 04:08:34.371233: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753675714.404038   50123 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753675714.414270   50123 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [2025-07-28 04:08:39,885] [INFO] [real_accelerator.py:254:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-07-28 04:08:41,475] [INFO] [logging.py:107:log_dist] [Rank -1] [TorchCheckpointEngine] Initialized with serialization = False
# ...

# %%
# 填写你自己的 GitHub 信息
username = "guokuir"  # 例如 krdeyou
repo = "HARE-rerun"          # 例如 hare-hate-speech
email = "2045982351@qq.com"
token = "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"        # GitHub token，例如 ghp_123abc...

# 配置 Git 身份
# !git config --global user.name "{username}"
# !git config --global user.email "{email}"

# 进入项目目录
# %cd /content/hare-hate-speech

# 移除原来的远程 origin（避免重复）
# !git remote remove origin

# 添加新的远程地址（带 token）
# !git remote add origin https://{username}:{token}@github.com/{username}/{repo}.git
# Out:
# /content/hare-hate-speech

# %%
# !git add .
# !git commit -m "更新说明：运行2个baseline"
# !git push origin main
# Out:
# [main 15506b6] 更新说明：运行2个baseline
#  2 files changed, 8 insertions(+), 8 deletions(-)
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 713 bytes | 713.00 KiB/s, done.
# Total 5 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 3 local objects.
# To https://github.com/guokuir/HARE-rerun.git
#    0dbb28f..15506b6  main -> main

# %%
# 保存 Notebook 到你的项目文件夹
# !cp /content/drive/MyDrive/Colab-Notebooks/HATE.ipynb /content/hare-hate-speech/

# 添加并提交
# !cd /content/hare-hate-speech/
# !git add HATE.ipynb
# !git commit -m "Add new notebook"
# !git push origin main
# Out:
# cp: cannot stat '/content/drive/MyDrive/Colab': No such file or directory
# cp: cannot stat 'Notebooks/HATE.ipynb': No such file or directory
# fatal: pathspec 'HATE.ipynb' did not match any files
# On branch main
# nothing to commit, working tree clean
# Everything up-to-date
